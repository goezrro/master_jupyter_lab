# %% [markdown]
# <h1>Ventas en Publicidad</h1>

# %% [markdown]
# Crear y evaluar un modelo de **regresión lineal múltiple** para predecir las ventas con datos simulados de una empresa dependiendo de las inversiones realizadas en publicidad.

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm # Estadísticas R Adjused
import seaborn as sns  # Gráficos
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures # Polinomial
from scipy import stats
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.metrics import mean_squared_error, r2_score
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
datos = pd.read_csv("https://raw.githubusercontent.com/rpizarrog/Analisis-Inteligente-de-datos/main/datos/Advertising_Web.csv")

# %%
datos
# Out:
#      Unnamed: 0    X     TV  Radio  Newspaper         Web  Sales
# 0             1    1  230.1   37.8       69.2  306.634752   22.1
# 1             2    2   44.5   39.3       45.1  302.653070   10.4
# 2             3    3   17.2   45.9       69.3   49.498908    9.3
# 3             4    4  151.5   41.3       58.5  257.816893   18.5
# 4             5    5  180.8   10.8       58.4  195.660076   12.9
# ..          ...  ...    ...    ...        ...         ...    ...
# 195         196  196   38.2    3.7       13.8  248.841073    7.6
# 196         197  197   94.2    4.9        8.1  118.041856    9.7
# 197         198  198  177.0    9.3        6.4  213.274671   12.8
# 198         199  199  283.6   42.0       66.2  237.498063   25.5
# 199         200  200  232.1    8.6        8.7  151.990733   13.4
#
# [200 rows x 7 columns]

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   X           200 non-null    int64
#  2   TV          200 non-null    float64
#  3   Radio       200 non-null    float64
#  4   Newspaper   200 non-null    float64
#  5   Web         200 non-null    float64
#  6   Sales       200 non-null    float64
# dtypes: float64(5), int64(2)
# memory usage: 11.1 KB

# %% [markdown]
# Se describen las variables independientes: *TV, Radio, Newspaper* y *Web*.
#
# Se describe la variable dependiente *Sales*: significa el volumen de ventas del producto correspondiente.
#
# Para un solo producto en un mercado determinado, el costo de la publicidad, en miles, de las variables independientes:
#
# -**TV**: costos de publicidad invertidos en TV.
#
# -**Radio**: costos de publicidad invertidos en radio.
#
# -**Periódico**: costos de publicidad invertidos en medios periodísticos.
#
# -**Web**: costos de publicidad invertidos en páginas web.

# %%
datos.describe()
# Out:
#        Unnamed: 0           X          TV       Radio   Newspaper         Web  \
# count  200.000000  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  100.500000  147.042500   23.264000   30.554000  159.587355
# std     57.879185   57.879185   85.854236   14.846809   21.778621   76.815266
# min      1.000000    1.000000    0.700000    0.000000    0.300000    4.308085
# 25%     50.750000   50.750000   74.375000    9.975000   12.750000   99.048767
# 50%    100.500000  100.500000  149.750000   22.900000   25.750000  156.862154
# 75%    150.250000  150.250000  218.825000   36.525000   45.100000  212.311848
# max    200.000000  200.000000  296.400000   49.600000  114.000000  358.247042
#
#             Sales
# count  200.000000
# mean    14.022500
# std      5.217457
# min      1.600000
# 25%     10.375000
# 50%     12.900000
# 75%     17.400000
# max     27.000000

# %%
datos.head()
# Out:
#    Unnamed: 0  X     TV  Radio  Newspaper         Web  Sales
# 0           1  1  230.1   37.8       69.2  306.634752   22.1
# 1           2  2   44.5   39.3       45.1  302.653070   10.4
# 2           3  3   17.2   45.9       69.3   49.498908    9.3
# 3           4  4  151.5   41.3       58.5  257.816893   18.5
# 4           5  5  180.8   10.8       58.4  195.660076   12.9

# %%
datos.tail()
# Out:
#      Unnamed: 0    X     TV  Radio  Newspaper         Web  Sales
# 195         196  196   38.2    3.7       13.8  248.841073    7.6
# 196         197  197   94.2    4.9        8.1  118.041856    9.7
# 197         198  198  177.0    9.3        6.4  213.274671   12.8
# 198         199  199  283.6   42.0       66.2  237.498063   25.5
# 199         200  200  232.1    8.6        8.7  151.990733   13.4

# %%
sns.pairplot(datos, x_vars=['TV', 'Radio', 'Newspaper', 'Web'], y_vars='Sales',
             height=7, aspect=0.8, kind = 'reg')
plt.xlabel("Web")
plt.ylabel("Sales")
plt.show()

# %% [markdown]
# Se muestra las relaciones lineales entre las variables independientes con respecto a *Sales*.
#
# Es posible estimar visualmente que la variable *Newspaper* tal vez tenga poco impacto en las *Sales*, esto por la alta dispersión de los datos. Sin embargo participará en el modelo de regresión lineal múltiple.
#
# Se observa también que la variable *Web* tiene poca correlación lineal con la variable *Sales*.

# %%
# creamos un dataset con las variables predictoras
X_independientes = datos.iloc[:,2:6]
X_independientes.head()
# Out:
#       TV  Radio  Newspaper         Web
# 0  230.1   37.8       69.2  306.634752
# 1   44.5   39.3       45.1  302.653070
# 2   17.2   45.9       69.3   49.498908
# 3  151.5   41.3       58.5  257.816893
# 4  180.8   10.8       58.4  195.660076

# %%
# aislamos la variable respuesta
Y_dependiente = datos.iloc[:, 6:7]
Y_dependiente.head()
# Out:
#    Sales
# 0   22.1
# 1   10.4
# 2    9.3
# 3   18.5
# 4   12.9

# %%
#crear matriz de correlación
corr = datos.corr()
corr.style.background_gradient()
# Out:
# <style type="text/css">
# #T_071e7_row0_col0, #T_071e7_row0_col1, #T_071e7_row1_col0, #T_071e7_row1_col1, #T_071e7_row2_col2, #T_071e7_row3_col3, #T_071e7_row4_col4, #T_071e7_row5_col5, #T_071e7_row6_col6 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_071e7_row0_col2, #T_071e7_row1_col2 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_071e7_row0_col3, #T_071e7_row1_col3 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_071e7_row0_col4, #T_071e7_row0_col6, #T_071e7_row1_col4, #T_071e7_row1_col6, #T_071e7_row3_col5, #T_071e7_row4_col0, #T_071e7_row4_col1, #T_071e7_row5_col2, #T_071e7_row5_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_071e7_row0_col5, #T_071e7_row1_col5 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_071e7_row2_col0, #T_071e7_row2_col1 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_071e7_row2_col3 {
#   background-color: #e5e1ef;
#   color: #000000;
# }
# #T_071e7_row2_col4 {
#   background-color: #e0dded;
#   color: #000000;
# }
# #T_071e7_row2_col5 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_071e7_row2_col6 {
#   background-color: #0569a4;
#   color: #f1f1f1;
# }
# #T_071e7_row3_col0, #T_071e7_row3_col1 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_071e7_row3_col2 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_071e7_row3_col4 {
#   background-color: #8cb3d5;
#   color: #000000;
# }
# #T_071e7_row3_col6 {
#   background-color: #4496c3;
#   color: #f1f1f1;
# }
# #T_071e7_row4_col2 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_071e7_row4_col3 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_071e7_row4_col5, #T_071e7_row5_col6 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_071e7_row4_col6 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_071e7_row5_col0, #T_071e7_row5_col1, #T_071e7_row5_col4, #T_071e7_row6_col0, #T_071e7_row6_col1 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_071e7_row6_col2 {
#   background-color: #056ba7;
#   color: #f1f1f1;
# }
# #T_071e7_row6_col3 {
#   background-color: #3790c0;
#   color: #f1f1f1;
# }
# #T_071e7_row6_col4 {
#   background-color: #b5c4df;
#   color: #000000;
# }
# #T_071e7_row6_col5 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# </style>
# <table id="T_071e7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_071e7_level0_col0" class="col_heading level0 col0" >Unnamed: 0</th>
#       <th id="T_071e7_level0_col1" class="col_heading level0 col1" >X</th>
#       <th id="T_071e7_level0_col2" class="col_heading level0 col2" >TV</th>
#       <th id="T_071e7_level0_col3" class="col_heading level0 col3" >Radio</th>
#       <th id="T_071e7_level0_col4" class="col_heading level0 col4" >Newspaper</th>
#       <th id="T_071e7_level0_col5" class="col_heading level0 col5" >Web</th>
#       <th id="T_071e7_level0_col6" class="col_heading level0 col6" >Sales</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_071e7_level0_row0" class="row_heading level0 row0" >Unnamed: 0</th>
#       <td id="T_071e7_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_071e7_row0_col1" class="data row0 col1" >1.000000</td>
#       <td id="T_071e7_row0_col2" class="data row0 col2" >0.017715</td>
#       <td id="T_071e7_row0_col3" class="data row0 col3" >-0.110680</td>
#       <td id="T_071e7_row0_col4" class="data row0 col4" >-0.154944</td>
#       <td id="T_071e7_row0_col5" class="data row0 col5" >-0.052173</td>
#       <td id="T_071e7_row0_col6" class="data row0 col6" >-0.051616</td>
#     </tr>
#     <tr>
#       <th id="T_071e7_level0_row1" class="row_heading level0 row1" >X</th>
#       <td id="T_071e7_row1_col0" class="data row1 col0" >1.000000</td>
#       <td id="T_071e7_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_071e7_row1_col2" class="data row1 col2" >0.017715</td>
#       <td id="T_071e7_row1_col3" class="data row1 col3" >-0.110680</td>
#       <td id="T_071e7_row1_col4" class="data row1 col4" >-0.154944</td>
#       <td id="T_071e7_row1_col5" class="data row1 col5" >-0.052173</td>
#       <td id="T_071e7_row1_col6" class="data row1 col6" >-0.051616</td>
#     </tr>
#     <tr>
#       <th id="T_071e7_level0_row2" class="row_heading level0 row2" >TV</th>
#       <td id="T_071e7_row2_col0" class="data row2 col0" >0.017715</td>
#       <td id="T_071e7_row2_col1" class="data row2 col1" >0.017715</td>
#       <td id="T_071e7_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_071e7_row2_col3" class="data row2 col3" >0.054809</td>
#       <td id="T_071e7_row2_col4" class="data row2 col4" >0.056648</td>
#       <td id="T_071e7_row2_col5" class="data row2 col5" >0.012576</td>
#       <td id="T_071e7_row2_col6" class="data row2 col6" >0.782224</td>
#     </tr>
#     <tr>
#       <th id="T_071e7_level0_row3" class="row_heading level0 row3" >Radio</th>
#       <td id="T_071e7_row3_col0" class="data row3 col0" >-0.110680</td>
#       <td id="T_071e7_row3_col1" class="data row3 col1" >-0.110680</td>
#       <td id="T_071e7_row3_col2" class="data row3 col2" >0.054809</td>
#       <td id="T_071e7_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_071e7_row3_col4" class="data row3 col4" >0.354104</td>
#       <td id="T_071e7_row3_col5" class="data row3 col5" >-0.122673</td>
#       <td id="T_071e7_row3_col6" class="data row3 col6" >0.576223</td>
#     </tr>
#     <tr>
#       <th id="T_071e7_level0_row4" class="row_heading level0 row4" >Newspaper</th>
#       <td id="T_071e7_row4_col0" class="data row4 col0" >-0.154944</td>
#       <td id="T_071e7_row4_col1" class="data row4 col1" >-0.154944</td>
#       <td id="T_071e7_row4_col2" class="data row4 col2" >0.056648</td>
#       <td id="T_071e7_row4_col3" class="data row4 col3" >0.354104</td>
#       <td id="T_071e7_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_071e7_row4_col5" class="data row4 col5" >-0.057759</td>
#       <td id="T_071e7_row4_col6" class="data row4 col6" >0.228299</td>
#     </tr>
#     <tr>
#       <th id="T_071e7_level0_row5" class="row_heading level0 row5" >Web</th>
#       <td id="T_071e7_row5_col0" class="data row5 col0" >-0.052173</td>
#       <td id="T_071e7_row5_col1" class="data row5 col1" >-0.052173</td>
#       <td id="T_071e7_row5_col2" class="data row5 col2" >0.012576</td>
#       <td id="T_071e7_row5_col3" class="data row5 col3" >-0.122673</td>
#       <td id="T_071e7_row5_col4" class="data row5 col4" >-0.057759</td>
#       <td id="T_071e7_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_071e7_row5_col6" class="data row5 col6" >0.002108</td>
#     </tr>
#     <tr>
#       <th id="T_071e7_level0_row6" class="row_heading level0 row6" >Sales</th>
#       <td id="T_071e7_row6_col0" class="data row6 col0" >-0.051616</td>
#       <td id="T_071e7_row6_col1" class="data row6 col1" >-0.051616</td>
#       <td id="T_071e7_row6_col2" class="data row6 col2" >0.782224</td>
#       <td id="T_071e7_row6_col3" class="data row6 col3" >0.576223</td>
#       <td id="T_071e7_row6_col4" class="data row6 col4" >0.228299</td>
#       <td id="T_071e7_row6_col5" class="data row6 col5" >0.002108</td>
#       <td id="T_071e7_row6_col6" class="data row6 col6" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
#se construye el modelo de regresión
modelo_rm = LinearRegression()
modelo_rm.fit(X_independientes, Y_dependiente)
# Out:
# LinearRegression()

# %%
# obtener coeficientes del modelo
# intercepto
print(modelo_rm.intercept_)
# Out:
# [2.2442222]

# %%
# coeficientes de regresión
print(modelo_rm.coef_)
# Out:
# [[ 0.04569278  0.19097499 -0.00079352  0.00401598]]

# %% [markdown]
# Predicción:
#
# $$
# Y=b_0+b_1⋅x_1+b_2⋅x_2+b_3⋅x_3+b_3⋅x_4
# $$
#
# Predicción de *Sales*:
#
# $$
# \text{Sales}=b_0+b_1⋅\text{TV}+b_2⋅\text{Radio}+b_3⋅\text{Newspaper}+b_4⋅\text{Web}
# $$

# %%
# definir matriz de diseño y variable respuesta
X = X_independientes
y = Y_dependiente

# añadir intercepto
X2 = sm.add_constant(X)

# ajustar el modelo
est = sm.OLS(y, X2)

# ver ajuste
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Sales   R-squared:                       0.901
# Model:                            OLS   Adj. R-squared:                  0.899
# Method:                 Least Squares   F-statistic:                     441.9
# Date:                Fri, 03 May 2024   Prob (F-statistic):           1.48e-96
# Time:                        11:14:46   Log-Likelihood:                -382.78
# No. Observations:                 200   AIC:                             775.6
# Df Residuals:                     195   BIC:                             792.0
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.2442      0.407      5.509      0.000       1.441       3.048
# TV             0.0457      0.001     33.228      0.000       0.043       0.048
# Radio          0.1910      0.009     22.364      0.000       0.174       0.208
# Newspaper     -0.0008      0.006     -0.137      0.891      -0.012       0.011
# Web            0.0040      0.002      2.599      0.010       0.001       0.007
# ==============================================================================
# Omnibus:                       61.291   Durbin-Watson:                   2.071
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              166.901
# Skew:                          -1.307   Prob(JB):                     5.73e-37
# Kurtosis:                       6.632   Cond. No.                         814.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
print("Predicción: ", modelo_rm.predict ([[296.400000, 49.600000, 114.000000, 358.247042]]))
# Out:
# Predicción:  [[26.608175]]
# /Users/danielgonzalez/opt/anaconda3/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
predicciones = modelo_rm.predict(X_independientes)

# %%
comparaciones = pd.DataFrame(X_independientes)
comparaciones = comparaciones.assign(Sales_Real = Y_dependiente)
comparaciones = comparaciones.assign(Sales_Predicho = predicciones.flatten().tolist())
comparaciones.head()
# Out:
#       TV  Radio  Newspaper         Web  Sales_Real  Sales_Predicho
# 0  230.1   37.8       69.2  306.634752        22.1       21.153514
# 1   44.5   39.3       45.1  302.653070        10.4       12.962530
# 2   17.2   45.9       69.3   49.498908         9.3       11.939686
# 3  151.5   41.3       58.5  257.816893        18.5       18.042913
# 4  180.8   10.8       58.4  195.660076        12.9       13.307433

# %%
print('Mean Squared Error: MSE', metrics.mean_squared_error(Y_dependiente, predicciones))
# Out:
# Mean Squared Error: MSE 2.690921581107243

# %%
print('Root Mean Squared Error RMSE:', np.sqrt(metrics.mean_squared_error(Y_dependiente, predicciones)))
# Out:
# Root Mean Squared Error RMSE: 1.6404028715858927

# %%
# Variance Inflation Factor
# crear dataframe para aplicar VIF
VIF = pd.DataFrame()
VIF["variable"] = X_independientes.columns

# %%
# aplicar el método
VIF["VIF"] = [variance_inflation_factor(X_independientes.values, i)
                  for i in range(len(X_independientes.columns))]

# resultados
VIF
# Out:
#     variable       VIF
# 0         TV  3.172879
# 1      Radio  3.427062
# 2  Newspaper  3.191014
# 3        Web  3.088313

# %% [markdown]
# Fin
